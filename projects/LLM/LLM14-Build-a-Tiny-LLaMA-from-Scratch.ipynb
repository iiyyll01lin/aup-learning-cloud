# %% [markdown]
# # LLM14: Build a Tiny LLaMA from Scratch
#
# ## Lab Overview
#
# Welcome! Earlier labs focused on attention math and components; here you put those pieces together into a **real model** that can tokenize, train on toy data, and generate text. In this hands-on lab you will implement a minimal, fully working **LLaMA-style decoder-only transformer** from scratch, without using `transformers` for the model itself.
#
# We **prioritize educational clarity and correctness** (masks, RoPE, RMSNorm, SwiGLU, weight tying, etc.), with a tiny configuration so everything runs on AMD GPUs.
#
# #### Recommended Hardware
#
# AMD Ryzen™ AI Halo Processors (e.g., AI Max+ 395, AI Max 390)
#
# #### Software Environment
#
# OS: Ubuntu 24.04.3 LTS \
# Install [AUP Learning Cloud](https://amdresearch.github.io/aup-learning-cloud/installation/quick-start.html?family=ryzen-ai&gpu=…). After installing AUP Learning Cloud, you will have a ROCm and PyTorch environment that is compatible with this notebook.
#
# ## Goals
#
# By the end, you will be able to:
#
# 1. Implement the **LLaMA block** (RMSNorm → RoPE → MHA → SwiGLU MLP → residuals).
# 2. Use **PyTorch SDPA** (`scaled_dot_product_attention`) for efficient, numerically-stable attention with **causal masking** and **padding masks**.
# 3. Apply **Rotary Position Embeddings (RoPE)** correctly to Q/K.
# 4. Implement **RMSNorm** and **SwiGLU** as in modern LLaMA variants.
# 5. Do **weight tying** between token embedding and LM head.
# 6. Train a toy model end-to-end and **generate** text with greedy decoding.
#
# ---

# %% [markdown]
# ## 1. Environment Setup

# %%
# Core libraries for custom architectures
import math
import os
import warnings

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

warnings.filterwarnings("ignore")

# Configure device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
print(f"PyTorch version: {torch.__version__}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

# Set random seeds for reproducibility
torch.manual_seed(42)
if device.type == "cuda":
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)

print("Environment ready for Tiny LLaMA implementation")
# Out:
# Using device: cuda
# PyTorch version: 2.9.1+rocm7.2.0.git7e1940d4
# GPU: AMD Radeon(TM) 8060S Graphics
# GPU Memory: 102.7 GB
# Environment ready for Tiny LLaMA implementation

# %% [markdown]
# ## 2. Tiny Byte‑Level Tokenizer (No External Files)
#
# To keep this truly self-contained, we’ll use a **byte tokenizer**: each UTF‑8 byte (0–255) is a token. This is simple and works for any text.
#
# **Trade‑off:** This is not BPE, but it avoids any external dependencies. It’s perfect for a small demo.

# %%
class ByteTokenizer:
    def __init__(self, vocab_size=256):
        assert vocab_size == 256, "This simple tokenizer maps bytes 0..255."
        self.vocab_size = 256

    def encode(self, text: str):
        return list(text.encode("utf-8"))

    def decode(self, ids):
        return bytes([int(i) % 256 for i in ids]).decode("utf-8", errors="replace")


tokenizer = ByteTokenizer()
vocab_size = tokenizer.vocab_size
print("Tokenizer ready. Vocab size:", vocab_size)
# Out:
# Tokenizer ready. Vocab size: 256

# %% [markdown]
# ## 3. LLaMA Building Blocks (RMSNorm, RoPE, SwiGLU)
#
# We define the following useful components for later usage:
#
# - **RMSNorm** (no mean-centering) is simple and stable.
# - **RoPE** rotates Q/K to inject positions.
# - **SwiGLU** gates the MLP.

# %%
class RMSNorm(nn.Module):
    def __init__(self, dim: int, eps: float = 1e-5):
        super().__init__()
        self.weight = nn.Parameter(torch.ones(dim))
        self.eps = eps

    def forward(self, x):
        norm = x.pow(2).mean(dim=-1, keepdim=True).add(self.eps).rsqrt()
        return self.weight * x * norm


def rotate_half(x):  # x: [..., Dh], Dh must be even
    x1, x2 = x.chunk(2, dim=-1)
    return torch.cat([-x2, x1], dim=-1)


def rope_apply(q, k, cos, sin):
    """
    q, k: [B, H, T, Dh]
    cos, sin: [1, 1, T, Dh] (already reshaped for broadcasting)
    """
    q_out = (q * cos) + (rotate_half(q) * sin)
    k_out = (k * cos) + (rotate_half(k) * sin)
    return q_out, k_out


class RotaryEmbedding(nn.Module):
    def __init__(self, dim: int, base: float = 10000.0, max_seq_len: int = 2048):
        super().__init__()
        assert dim % 2 == 0, "RoPE dim must be even."
        inv_freq = 1.0 / (base ** (torch.arange(0, dim, 2).float() / dim))  # [Dh/2]
        t = torch.arange(max_seq_len, dtype=torch.float32)  # [T]
        freqs = torch.einsum("i,j->ij", t, inv_freq)  # [T, Dh/2]
        emb = torch.cat([freqs, freqs], dim=-1)  # [T, Dh]
        self.register_buffer("cos_cached", emb.cos(), persistent=False)  # [T, Dh]
        self.register_buffer("sin_cached", emb.sin(), persistent=False)  # [T, Dh]

    def get_cos_sin(self, seq_len: int):
        return self.cos_cached[:seq_len], self.sin_cached[:seq_len]


class SwiGLU(nn.Module):
    def __init__(self, dim_in: int, dim_hidden: int):
        super().__init__()
        self.w1 = nn.Linear(dim_in, dim_hidden, bias=False)
        self.w2 = nn.Linear(dim_in, dim_hidden, bias=False)
        self.w3 = nn.Linear(dim_hidden, dim_in, bias=False)

    def forward(self, x):
        return self.w3(torch.nn.functional.silu(self.w1(x)) * self.w2(x))


print("Components defined.")
# Out:
# Components defined.

# %% [markdown]
# ## 4. Multi-Head Attention (SDPA, Causal + Padding Masks)
#
# We define our multi-head attention block using PyTorch's built-in SDPA
# (`scaled_dot_product_attention`) for speed and numerical stability.
# `is_causal=True` applies the causal mask automatically.
# If a padding mask is provided, `True` means that key position is masked out.

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, dim: int, n_heads: int, rope: RotaryEmbedding, dropout: float = 0.0):
        super().__init__()
        assert dim % n_heads == 0
        self.dim = dim
        self.n_heads = n_heads
        self.head_dim = dim // n_heads
        self.qkv = nn.Linear(dim, 3 * dim, bias=False)
        self.out = nn.Linear(dim, dim, bias=False)
        self.rope = rope
        self.dropout_p = dropout

    def forward(self, x, key_padding_mask=None):
        B, T, D = x.shape
        qkv = self.qkv(x)
        q, k, v = qkv.split(D, dim=-1)

        def to_heads(t):
            return t.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)

        qh, kh, vh = map(to_heads, (q, k, v))

        cos, sin = self.rope.get_cos_sin(T)
        cos = cos.to(qh.dtype).to(qh.device)[None, None, :, :]
        sin = sin.to(qh.dtype).to(qh.device)[None, None, :, :]
        qh, kh = rope_apply(qh, kh, cos, sin)

        attn_mask = None
        if key_padding_mask is not None:
            attn_mask = key_padding_mask[:, None, None, :].expand(B, 1, T, T)

        out = torch.nn.functional.scaled_dot_product_attention(
            qh,
            kh,
            vh,
            attn_mask=attn_mask,
            dropout_p=self.dropout_p if self.training else 0.0,
            is_causal=True,
        )
        out = out.transpose(1, 2).contiguous().view(B, T, D)
        return self.out(out)


print("Multi-head attention is defined.")
# Out:
# Multi-head attention is defined.

# %% [markdown]
# ## 5. LLaMA Block and Model
#
# We now integrate the components together with the following structure:
#
# LLaMA block =
# RMSNorm → MHA → residual → RMSNorm → SwiGLU MLP → residual.
#
# We also tie embedding ↔ LM head weights.

# %%
class LLaMABlock(nn.Module):
    def __init__(self, dim: int, n_heads: int, mlp_ratio: float, rope: RotaryEmbedding, dropout: float = 0.0):
        super().__init__()
        self.norm1 = RMSNorm(dim)
        self.attn = MultiHeadAttention(dim, n_heads, rope, dropout=dropout)
        self.norm2 = RMSNorm(dim)
        hidden = int(mlp_ratio * dim)
        self.mlp = SwiGLU(dim, hidden)

    def forward(self, x, key_padding_mask=None):
        x = x + self.attn(self.norm1(x), key_padding_mask=key_padding_mask)
        x = x + self.mlp(self.norm2(x))
        return x


class LLaMAFromScratch(nn.Module):
    def __init__(
        self,
        vocab_size: int,
        dim: int = 256,
        n_layers: int = 4,
        n_heads: int = 8,
        mlp_ratio: float = 4.0,
        max_seq_len: int = 256,
        dropout: float = 0.0,
    ):
        super().__init__()
        assert dim % n_heads == 0
        self.vocab_size = vocab_size
        self.dim = dim
        self.max_seq_len = max_seq_len
        self.embed = nn.Embedding(vocab_size, dim)
        self.rope = RotaryEmbedding(dim // n_heads, max_seq_len=max_seq_len)
        self.blocks = nn.ModuleList(
            [LLaMABlock(dim, n_heads, mlp_ratio, self.rope, dropout=dropout) for _ in range(n_layers)]
        )
        self.norm_f = RMSNorm(dim)
        self.lm_head = nn.Linear(dim, vocab_size, bias=False)
        self.lm_head.weight = self.embed.weight  # weight tying

        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            fan_in = m.weight.shape[1]
            std = 0.02 / math.sqrt(max(1, fan_in))
            with torch.no_grad():
                nn.init.trunc_normal_(m.weight, mean=0.0, std=std, a=-2 * std, b=2 * std)
                if getattr(m, "bias", None) is not None:
                    nn.init.zeros_(m.bias)
        elif isinstance(m, nn.Embedding):
            with torch.no_grad():
                nn.init.normal_(m.weight, mean=0.0, std=0.02)

    def forward(self, input_ids, key_padding_mask=None):
        B, T = input_ids.shape
        if self.max_seq_len < T:
            raise ValueError(f"Sequence length {T} exceeds max_seq_len={self.max_seq_len}.")
        x = self.embed(input_ids)
        for blk in self.blocks:
            x = blk(x, key_padding_mask=key_padding_mask)
        x = self.norm_f(x)
        logits = self.lm_head(x)
        return logits

    @torch.no_grad()
    def generate(self, input_ids, max_new_tokens=50):
        self.eval()
        out = input_ids.clone().to(next(self.parameters()).device)
        for _ in range(max_new_tokens):
            tokens = out[:, -self.max_seq_len :]
            logits = self(tokens)
            next_token = logits[:, -1, :].argmax(dim=-1, keepdim=True)
            out = torch.cat([out, next_token], dim=1)
        return out


print("Attention computational block is defined.")
# Out:
# Attention computational block is defined.

# %% [markdown]
# ## 6. Tiny Sanity Tests
#
# Build a small model and check shapes/parameter counts.

# %%
cfg = {"vocab_size": 256, "dim": 192, "n_layers": 3, "n_heads": 6, "mlp_ratio": 4.0, "max_seq_len": 128, "dropout": 0.0}
model = LLaMAFromScratch(**cfg).to(device)
n_params = sum(p.numel() for p in model.parameters())
print(model)
print(f"Total parameters: {n_params:,}")
# Out:
# LLaMAFromScratch(
#   (embed): Embedding(256, 192)
#   (rope): RotaryEmbedding()
#   (blocks): ModuleList(
#     (0-2): 3 x LLaMABlock(
#       (norm1): RMSNorm()
#       (attn): MultiHeadAttention(
#         (qkv): Linear(in_features=192, out_features=576, bias=False)
#         (out): Linear(in_features=192, out_features=192, bias=False)
#         (rope): RotaryEmbedding()
#       )
#       (norm2): RMSNorm()
#       (mlp): SwiGLU(
#         (w1): Linear(in_features=192, out_features=768, bias=False)
#         (w2): Linear(in_features=192, out_features=768, bias=False)
#         (w3): Linear(in_features=768, out_features=192, bias=False)
#       )
#     )
#   )
#   (norm_f): RMSNorm()
#   (lm_head): Linear(in_features=192, out_features=256, bias=False)
# )
# Total parameters: 1,819,968

# %% [markdown]
# ## 7. Toy Dataset & Training Loop
#
# We train on a tiny corpus to verify the loss goes down (next-token prediction).
#
# This section is only for a minimal end-to-end demo, not for meaningful language modeling quality.
#
# If training runs too slowly on your machine, reduce the number of epochs in the training loop below.

# %%
from contextlib import nullcontext

# designed in part 2
tokenizer = ByteTokenizer()

text_corpus = [
    "LLaMA from scratch.\n",
    "We build a tiny decoder-only Transformer.\n",
    "This is educational and runs on CPU or GPU.\n",
    "Attention with RoPE and RMSNorm works well.\n",
    "SwiGLU MLP and weight tying included.\n",
]
data = tokenizer.encode("".join(text_corpus))
print("Toy corpus bytes:", len(data))


def make_batches(data, seq_len=64, batch_size=8):
    X, Y = [], []
    for i in range(0, len(data) - seq_len - 1, seq_len):
        x = data[i : i + seq_len]
        y = data[i + 1 : i + seq_len + 1]
        X.append(x)
        Y.append(y)
        if len(X) == batch_size:
            xb = torch.tensor(X, dtype=torch.long, device=device)
            yb = torch.tensor(Y, dtype=torch.long, device=device)
            yield xb, yb
            X, Y = [], []
    if X:
        xb = torch.tensor(X, dtype=torch.long, device=device)
        yb = torch.tensor(Y, dtype=torch.long, device=device)
        yield xb, yb


optim = torch.optim.AdamW(model.parameters(), lr=3e-3, weight_decay=0.01)
scaler = torch.cuda.amp.GradScaler(enabled=(device.type == "cuda"))
loss_fn = nn.CrossEntropyLoss()


def train_one_epoch(epoch, seq_len=64, batch_size=8):
    model.train()
    losses = []
    for xb, yb in make_batches(data, seq_len=seq_len, batch_size=batch_size):
        optim.zero_grad(set_to_none=True)
        amp_ctx = torch.autocast(device_type="cuda", dtype=torch.bfloat16) if device.type == "cuda" else nullcontext()

        with amp_ctx:
            logits = model(xb)
            loss = loss_fn(logits.reshape(-1, logits.size(-1)), yb.reshape(-1))
        scaler.scale(loss).backward()
        scaler.step(optim)
        scaler.update()
        losses.append(loss.item())
    print(f"Epoch {epoch} | loss={np.mean(losses):.4f}")


for epoch in range(1, 300):
    train_one_epoch(epoch)
# Out:
# Toy corpus bytes: 188
# Epoch 1 | loss=5.5427
# Epoch 2 | loss=5.0190
# Epoch 3 | loss=4.4568
# Epoch 4 | loss=3.9183
# Epoch 5 | loss=3.5620
# Epoch 6 | loss=3.3613
# Epoch 7 | loss=3.2661
# Epoch 8 | loss=3.2172
# Epoch 9 | loss=3.2004
# Epoch 10 | loss=3.1925
# Epoch 11 | loss=3.1823
# Epoch 12 | loss=3.1717
# Epoch 13 | loss=3.1674
# Epoch 14 | loss=3.1700
# Epoch 15 | loss=3.1636
# Epoch 16 | loss=3.1484
# Epoch 17 | loss=3.1434
# Epoch 18 | loss=3.1431
# Epoch 19 | loss=3.1375
# Epoch 20 | loss=3.1349
# Epoch 21 | loss=3.1251
# Epoch 22 | loss=3.1157
# Epoch 23 | loss=3.1102
# Epoch 24 | loss=3.1024
# Epoch 25 | loss=3.0931
# Epoch 26 | loss=3.0723
# Epoch 27 | loss=3.0373
# Epoch 28 | loss=2.9929
# Epoch 29 | loss=3.0079
# Epoch 30 | loss=3.0627
# Epoch 31 | loss=3.0247
# Epoch 32 | loss=2.9636
# Epoch 33 | loss=2.9319
# Epoch 34 | loss=2.9166
# Epoch 35 | loss=2.8987
# Epoch 36 | loss=2.8782
# Epoch 37 | loss=2.8638
# Epoch 38 | loss=2.8416
# Epoch 39 | loss=2.8131
# Epoch 40 | loss=2.7892
# Epoch 41 | loss=2.7645
# Epoch 42 | loss=2.7385
# Epoch 43 | loss=2.7364
# Epoch 44 | loss=2.7035
# Epoch 45 | loss=2.6693
# Epoch 46 | loss=2.6252
# Epoch 47 | loss=2.5654
# Epoch 48 | loss=2.5708
# Epoch 49 | loss=2.5423
# Epoch 50 | loss=2.5618
# Epoch 51 | loss=2.4639
# Epoch 52 | loss=2.5214
# Epoch 53 | loss=2.5395
# Epoch 54 | loss=2.4517
# Epoch 55 | loss=2.4767
# Epoch 56 | loss=2.3838
# Epoch 57 | loss=2.3800
# Epoch 58 | loss=2.3306
# Epoch 59 | loss=2.3131
# Epoch 60 | loss=2.2510
# Epoch 61 | loss=2.2386
# Epoch 62 | loss=2.2085
# Epoch 63 | loss=2.1316
# Epoch 64 | loss=2.0804
# Epoch 65 | loss=2.0697
# Epoch 66 | loss=2.0797
# Epoch 67 | loss=2.0793
# Epoch 68 | loss=2.0573
# Epoch 69 | loss=1.9470
# Epoch 70 | loss=1.9304
# Epoch 71 | loss=1.9208
# Epoch 72 | loss=1.8746
# Epoch 73 | loss=1.7966
# Epoch 74 | loss=1.7906
# Epoch 75 | loss=1.7552
# Epoch 76 | loss=1.7520
# Epoch 77 | loss=1.7306
# Epoch 78 | loss=1.6984
# Epoch 79 | loss=1.6214
# Epoch 80 | loss=1.5776
# Epoch 81 | loss=1.5676
# Epoch 82 | loss=1.5648
# Epoch 83 | loss=1.6689
# Epoch 84 | loss=1.8900
# Epoch 85 | loss=1.5774
# Epoch 86 | loss=1.7310
# Epoch 87 | loss=1.4575
# Epoch 88 | loss=1.5008
# Epoch 89 | loss=1.4048
# Epoch 90 | loss=1.4021
# Epoch 91 | loss=1.6677
# Epoch 92 | loss=1.6099
# Epoch 93 | loss=1.5273
# Epoch 94 | loss=1.4203
# Epoch 95 | loss=1.3925
# Epoch 96 | loss=1.3924
# Epoch 97 | loss=1.4398
# Epoch 98 | loss=1.2957
# Epoch 99 | loss=1.2006
# Epoch 100 | loss=1.1650
# Epoch 101 | loss=1.1574
# Epoch 102 | loss=1.1041
# Epoch 103 | loss=1.1209
# Epoch 104 | loss=1.3459
# Epoch 105 | loss=1.0673
# Epoch 106 | loss=0.9729
# Epoch 107 | loss=1.1196
# Epoch 108 | loss=1.3447
# Epoch 109 | loss=1.2731
# Epoch 110 | loss=1.2310
# Epoch 111 | loss=1.1549
# Epoch 112 | loss=1.0757
# Epoch 113 | loss=1.0863
# Epoch 114 | loss=1.0617
# Epoch 115 | loss=1.1332
# Epoch 116 | loss=0.9776
# Epoch 117 | loss=0.9978
# Epoch 118 | loss=0.8550
# Epoch 119 | loss=0.9386
# Epoch 120 | loss=0.9715
# Epoch 121 | loss=1.0077
# Epoch 122 | loss=1.0741
# Epoch 123 | loss=0.9238
# Epoch 124 | loss=0.9094
# Epoch 125 | loss=1.2162
# Epoch 126 | loss=1.0687
# Epoch 127 | loss=1.1555
# Epoch 128 | loss=0.9094
# Epoch 129 | loss=1.2816
# Epoch 130 | loss=1.4838
# Epoch 131 | loss=1.2194
# Epoch 132 | loss=1.2487
# Epoch 133 | loss=1.4523
# Epoch 134 | loss=1.2055
# Epoch 135 | loss=1.1072
# Epoch 136 | loss=1.0750
# Epoch 137 | loss=1.0295
# Epoch 138 | loss=0.9088
# Epoch 139 | loss=0.8021
# Epoch 140 | loss=0.7970
# Epoch 141 | loss=0.7442
# Epoch 142 | loss=0.7263
# Epoch 143 | loss=0.6363
# Epoch 144 | loss=0.6706
# Epoch 145 | loss=0.6981
# Epoch 146 | loss=0.6729
# Epoch 147 | loss=0.6393
# Epoch 148 | loss=0.5856
# Epoch 149 | loss=0.5028
# Epoch 150 | loss=0.5612
# Epoch 151 | loss=0.4974
# Epoch 152 | loss=0.4261
# Epoch 153 | loss=0.4360
# Epoch 154 | loss=1.2989
# Epoch 155 | loss=1.3118
# Epoch 156 | loss=1.0764
# Epoch 157 | loss=0.7935
# Epoch 158 | loss=0.9251
# Epoch 159 | loss=0.9477
# Epoch 160 | loss=0.7696
# Epoch 161 | loss=0.7471
# Epoch 162 | loss=0.6381
# Epoch 163 | loss=0.7608
# Epoch 164 | loss=0.7004
# Epoch 165 | loss=0.6048
# Epoch 166 | loss=0.6232
# Epoch 167 | loss=0.5525
# Epoch 168 | loss=0.4721
# Epoch 169 | loss=0.4430
# Epoch 170 | loss=0.4549
# Epoch 171 | loss=0.4528
# Epoch 172 | loss=0.3945
# Epoch 173 | loss=0.3738
# Epoch 174 | loss=0.3329
# Epoch 175 | loss=0.3483
# Epoch 176 | loss=0.2831
# Epoch 177 | loss=0.2883
# Epoch 178 | loss=0.2745
# Epoch 179 | loss=0.2618
# Epoch 180 | loss=0.2505
# Epoch 181 | loss=0.2093
# Epoch 182 | loss=0.2271
# Epoch 183 | loss=0.2452
# Epoch 184 | loss=0.2212
# Epoch 185 | loss=0.1638
# Epoch 186 | loss=0.1275
# Epoch 187 | loss=0.1314
# Epoch 188 | loss=0.1209
# Epoch 189 | loss=0.1018
# Epoch 190 | loss=0.0959
# Epoch 191 | loss=0.0918
# Epoch 192 | loss=0.0774
# Epoch 193 | loss=0.1101
# Epoch 194 | loss=0.0744
# Epoch 195 | loss=0.1088
# Epoch 196 | loss=0.1354
# Epoch 197 | loss=0.1000
# Epoch 198 | loss=0.1046
# Epoch 199 | loss=0.1081
# Epoch 200 | loss=0.0937
# Epoch 201 | loss=0.0800
# Epoch 202 | loss=0.0794
# Epoch 203 | loss=0.0733
# Epoch 204 | loss=0.0607
# Epoch 205 | loss=0.0576
# Epoch 206 | loss=0.0486
# Epoch 207 | loss=0.0455
# Epoch 208 | loss=0.0441
# Epoch 209 | loss=0.0365
# Epoch 210 | loss=0.0359
# Epoch 211 | loss=0.0398
# Epoch 212 | loss=0.0400
# Epoch 213 | loss=0.1124
# Epoch 214 | loss=0.0875
# Epoch 215 | loss=0.0735
# Epoch 216 | loss=0.0536
# Epoch 217 | loss=0.0414
# Epoch 218 | loss=0.0363
# Epoch 219 | loss=0.0356
# Epoch 220 | loss=0.0349
# Epoch 221 | loss=0.0339
# Epoch 222 | loss=0.0298
# Epoch 223 | loss=0.0257
# Epoch 224 | loss=0.0235
# Epoch 225 | loss=0.0216
# Epoch 226 | loss=0.0205
# Epoch 227 | loss=0.0198
# Epoch 228 | loss=0.0191
# Epoch 229 | loss=0.0184
# Epoch 230 | loss=0.0178
# Epoch 231 | loss=0.0174
# Epoch 232 | loss=0.0170
# Epoch 233 | loss=0.0167
# Epoch 234 | loss=0.0164
# Epoch 235 | loss=0.0161
# Epoch 236 | loss=0.0159
# Epoch 237 | loss=0.0156
# Epoch 238 | loss=0.0154
# Epoch 239 | loss=0.0152
# Epoch 240 | loss=0.0150
# Epoch 241 | loss=0.0148
# Epoch 242 | loss=0.0147
# Epoch 243 | loss=0.0145
# Epoch 244 | loss=0.0144
# Epoch 245 | loss=0.0142
# Epoch 246 | loss=0.0141
# Epoch 247 | loss=0.0140
# Epoch 248 | loss=0.0139
# Epoch 249 | loss=0.0139
# Epoch 250 | loss=0.0138
# Epoch 251 | loss=0.0137
# Epoch 252 | loss=0.0136
# Epoch 253 | loss=0.0135
# Epoch 254 | loss=0.0135
# Epoch 255 | loss=0.0134
# Epoch 256 | loss=0.0134
# Epoch 257 | loss=0.0133
# Epoch 258 | loss=0.0133
# Epoch 259 | loss=0.0132
# Epoch 260 | loss=0.0132
# Epoch 261 | loss=0.0131
# Epoch 262 | loss=0.0131
# Epoch 263 | loss=0.0131
# Epoch 264 | loss=0.0130
# Epoch 265 | loss=0.0130
# Epoch 266 | loss=0.0129
# Epoch 267 | loss=0.0129
# Epoch 268 | loss=0.0129
# Epoch 269 | loss=0.0128
# Epoch 270 | loss=0.0128
# Epoch 271 | loss=0.0128
# Epoch 272 | loss=0.0128
# Epoch 273 | loss=0.0127
# Epoch 274 | loss=0.0127
# Epoch 275 | loss=0.0127
# Epoch 276 | loss=0.0127
# Epoch 277 | loss=0.0126
# Epoch 278 | loss=0.0126
# Epoch 279 | loss=0.0126
# Epoch 280 | loss=0.0126
# Epoch 281 | loss=0.0126
# Epoch 282 | loss=0.0125
# Epoch 283 | loss=0.0125
# Epoch 284 | loss=0.0125
# Epoch 285 | loss=0.0125
# Epoch 286 | loss=0.0125
# Epoch 287 | loss=0.0125
# Epoch 288 | loss=0.0125
# Epoch 289 | loss=0.0124
# Epoch 290 | loss=0.0124
# Epoch 291 | loss=0.0124
# Epoch 292 | loss=0.0124
# Epoch 293 | loss=0.0124
# Epoch 294 | loss=0.0124
# Epoch 295 | loss=0.0123
# Epoch 296 | loss=0.0123
# Epoch 297 | loss=0.0123
# Epoch 298 | loss=0.0123
# Epoch 299 | loss=0.0123

# %% [markdown]
# ## 8. Greedy Text Generation
#
# Prompt and generate a few tokens using greedy decoding (`argmax` at each step).

# %%
prompt = "LLaMA"
inp = torch.tensor([tokenizer.encode(prompt)], dtype=torch.long, device=device)
out_ids = model.generate(inp, max_new_tokens=80)[0].tolist()
print(tokenizer.decode(out_ids))
# Out:
# LLaMA from scratch.
# We build a tiny decoder-only Transformer.
# Thitdbobu ttboirareebu

# %% [markdown]
# ## Conclusions
#
# ### Technical Concepts Learned
#
# - **RMSNorm Implementation**: Root Mean Square normalization without mean-centering for stable transformer training
# - **Rotary Position Embeddings (RoPE)**: Applying rotary embeddings to Q/K tensors with correct broadcasting for relative position encoding
# - **SwiGLU MLP**: Implementing gated linear units with SiLU activation for improved model expressivity
# - **PyTorch SDPA**: Using `scaled_dot_product_attention` for efficient causal masking and numerically stable attention
# - **Weight Tying**: Sharing parameters between token embedding and LM head to reduce model size
#
# ### Experiment Further
#
# - Add KV cache for O(T·d) per-step inference instead of recomputing full attention
# - Replace byte-level tokenizer with BPE (tiktoken/SentencePiece) for better sample efficiency
# - Implement learning rate warmup and cosine decay schedule for training stability
# - Add dropout to attention and MLP layers and tune RMSNorm epsilon for regularization
# - Enable mixed precision training (for example, BF16 where supported) and activation checkpointing for larger models

# %% [markdown]
# ---
#
# Copyright (C) 2025 Advanced Micro Devices, Inc. All rights reserved. Portions of this file consist of AI-generated content.
# SPDX-License-Identifier: MIT
